# %%
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import requests
from config import db_password

# %%
# Load data
protocol = "postgres"
user = "postgres"
location = "localhost"
port = "5433"
db = "video_game"

connection_string = f'{protocol}://{user}:{db_password}@{location}:{port}/{db}'
engine = create_engine(connection_string)

# %%
clean_df = pd.read_sql_table('steam',con=engine)
clean_df
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   2000-11-01        1
# 1           20       Team Fortress Classic   1999-04-01        1
# 2           30               Day of Defeat   2003-05-01        1
# 3           40          Deathmatch Classic   2001-06-01        1
# 4           50   Half-Life: Opposing Force   1999-11-01        1
# ...        ...                         ...          ...      ...
# 27156  1065230             Room of Pandora   2019-04-24        1
# 27157  1065570                   Cyber Gun   2019-04-23        1
# 27158  1065650            Super Star Blast   2019-04-24        1
# 27159  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 27160  1069460                   Rune Lord   2019-04-24        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# 1                   Valve                 Valve  windows;mac;linux
# 2                   Valve                 Valve  windows;mac;linux
# 3                   Valve                 Valve  windows;mac;linux
# 4        Gearbox Software                 Valve  windows;mac;linux
# ...                   ...                   ...                ...
# 27156         SHEN JIAWEI           SHEN JIAWEI            windows
# 27157      Semyon Maximov      BekkerDev Studio            windows
# 27158         EntwicklerX           EntwicklerX            windows
# 27159  Yustas Game Studio  Alawar Entertainment        windows;mac
# 27160    Adept Studios GD  Alawar Entertainment        windows;mac
#
#        required_age                                         categories  \
# 0                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 1                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 2                 0              Multi-player;Valve Anti-Cheat enabled
# 3                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 4                 0  Single-player;Multi-player;Valve Anti-Cheat en...
# ...             ...                                                ...
# 27156             0                   Single-player;Steam Achievements
# 27157             0                                      Single-player
# 27158             0  Single-player;Multi-player;Co-op;Shared/Split ...
# 27159             0                          Single-player;Steam Cloud
# 27160             0                          Single-player;Steam Cloud
#
#                        genres  ... genre_8  genre_9  genre_10  genre_11  \
# 0                      Action  ...    None     None      None      None
# 1                      Action  ...    None     None      None      None
# 2                      Action  ...    None     None      None      None
# 3                      Action  ...    None     None      None      None
# 4                      Action  ...    None     None      None      None
# ...                       ...  ...     ...      ...       ...       ...
# 27156  Adventure;Casual;Indie  ...    None     None      None      None
# 27157  Action;Adventure;Indie  ...    None     None      None      None
# 27158     Action;Casual;Indie  ...    None     None      None      None
# 27159  Adventure;Casual;Indie  ...    None     None      None      None
# 27160  Adventure;Casual;Indie  ...    None     None      None      None
#
#        genre_12  genre_13 genre_14  genre_15 genre_16 average_rating
# 0          None      None     None      None     None        63936.5
# 1          None      None     None      None     None         1975.5
# 2          None      None     None      None     None         1907.0
# 3          None      None     None      None     None          770.0
# 4          None      None     None      None     None         2769.0
# ...         ...       ...      ...       ...      ...            ...
# 27156      None      None     None      None     None            1.5
# 27157      None      None     None      None     None            4.5
# 27158      None      None     None      None     None            0.5
# 27159      None      None     None      None     None            1.0
# 27160      None      None     None      None     None            2.0
#
# [27161 rows x 35 columns]
