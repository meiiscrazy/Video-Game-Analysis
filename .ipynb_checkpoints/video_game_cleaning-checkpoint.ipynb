# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
file_path = './resources/clean_steam_games.csv'
steam_df = pd.read_csv(file_path, index_col=0)
steam_df

# %%
steam_df = steam_df.drop(columns=['all_reviews', 'original_price'])
steam_df

# %%
steam_df.dtypes

# %%
null_counts = steam_df['name'].isnull().sum()
print(null_counts)

# %%
steam_df.dropna(subset=['name'], how='all', inplace=True)

# %%
steam_df['popular_tags'].astype(str)

# %%
tag_df = steam_df['popular_tags'].str.split(',', expand=True).rename(columns = lambda x: "tag_"+str(x+1))
tag_df

# %%
tag_df['name'] = steam_df['name']

# %%
col_name = 'name'
first_col = tag_df.pop(col_name)
tag_df.insert(0, col_name, first_col)

# %%
tag_df.columns.tolist()

# %%
merged_df = pd.merge(steam_df, tag_df, on='name')
merged_df

# %%
merged_null_counts = merged_df['name'].isnull().sum()
print(merged_null_counts)

# %%
genre_df = steam_df['genre'].str.split(',', expand=True).rename(columns = lambda x: "genre_"+str(x+1))
genre_df

# %%
genre_df['name'] = steam_df['name']

# %%
col_name = 'name'
first_col = genre_df.pop(col_name)
genre_df.insert(0, col_name, first_col)

# %%
genre_df.columns.tolist()

# %%
game_df = pd.merge(merged_df, genre_df, on='name')
game_df

# %%
game_null_counts = game_df['name'].isnull().sum()
print(game_null_counts)

# %%
game_df.to_csv('steam.csv', index=False)

# %%
file_path = './resources/steamclean.csv'
new_steam_df = pd.read_csv(file_path, index_col=0)
new_steam_df
# Out:
# /Users/mei/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (28,29,30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                name release_date  english           developer  \
# appid
# 10                   Counter-Strike   2000-11-01        1               Valve
# 20            Team Fortress Classic   1999-04-01        1               Valve
# 30                    Day of Defeat   2003-05-01        1               Valve
# 40               Deathmatch Classic   2001-06-01        1               Valve
# 50        Half-Life: Opposing Force   1999-11-01        1    Gearbox Software
# ...                             ...          ...      ...                 ...
# 1065230             Room of Pandora   2019-04-24        1         SHEN JIAWEI
# ...

# %%
new_steam_df.dtypes
# Out:
# name                 object
# release_date         object
# english               int64
# developer            object
# publisher            object
# platforms            object
# required_age          int64
# categories           object
# genres               object
# steamspy_tags        object
# achievements          int64
# positive_ratings      int64
# negative_ratings      int64
# average_playtime      int64
# median_playtime       int64
# owners               object
# price               float64
# genre_1              object
# genre_2              object
# genre_3              object
# genre_4              object
# genre_5              object
# genre_6              object
# genre_7              object
# genre_8              object
# genre_9              object
# genre_10             object
# genre_11             object
# genre_12             object
# genre_13             object
# genre_14             object
# genre_15             object
# genre_16             object
# ...

# %%
new_steam_df[['name', 'developer', 'publisher', 'platforms', 'categories', 'genres', 'steamspy_tags',
            'owners', 'genre_1', 'genre_2', 'genre_3', 'genre_3', 'genre_4', 'genre_5', 'genre_6',
            'genre_7', 'genre_8', 'genre_9', 'genre_10', 'genre_11', 'genre_12', 'genre_12', 'genre_13',
            'genre_14', 'genre_15', 'genre_16']] = new_steam_df[['name', 'developer', 'publisher', 'platforms', 'categories', 'genres', 'steamspy_tags',
            'owners', 'genre_1', 'genre_2', 'genre_3', 'genre_3', 'genre_4', 'genre_5', 'genre_6',
            'genre_7', 'genre_8', 'genre_9', 'genre_10', 'genre_11', 'genre_12', 'genre_12', 'genre_13',
            'genre_14', 'genre_15', 'genre_16']].astype(str)

# %%
new_steam_df[['price', 'average_rating']] = new_steam_df[['price', 'average_rating']].astype(int)

# %%
new_steam_df.dtypes
# Out:
# name                object
# release_date        object
# english              int64
# developer           object
# publisher           object
# platforms           object
# required_age         int64
# categories          object
# genres              object
# steamspy_tags       object
# achievements         int64
# positive_ratings     int64
# negative_ratings     int64
# average_playtime     int64
# median_playtime      int64
# owners              object
# price                int64
# genre_1             object
# genre_2             object
# genre_3             object
# genre_4             object
# genre_5             object
# genre_6             object
# genre_7             object
# genre_8             object
# genre_9             object
# genre_10            object
# genre_11            object
# genre_12            object
# genre_13            object
# genre_14            object
# genre_15            object
# genre_16            object
# average_rating       int64
# ...

# %%
new_steam_df.to_csv('steamclean.csv', index=False)
